# %% [markdown]
# # Vectorize texts using TF-IDF and save the model

# %%
import os, sys

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.tfidf_vectorizer import vectorize_texts
from src.dataset import load_dataset, load_preprocessed_dataset

# %%
train_df, test_df = load_preprocessed_dataset()
# Out:
# Preprocessing tweets...
# ...
# 100%|██████████| 25958/25958 [00:02<00:00, 9059.72it/s]

# %%
X_tfidf = vectorize_texts(train_df['TEXT'])
print(f"TF-IDF特征矩阵形状: {X_tfidf.shape}")
print(f"TF-IDF特征矩阵形状: {X_tfidf}")
# Out:
# ['10' '100' '11' '12' '14' '15' '16' '17' '18' '1st' '20' '2016' '2017'
#  '2018' '21' '24' '25' '2nd' '30' '4th' '4th july' '50' 'able'
#  'absolutely' 'academy' 'actually' 'add' 'adventure' 'adventures' 'af']
# TF-IDF特征矩阵形状: (70000, 1000)
# TF-IDF特征矩阵形状: <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 227468 stored elements and shape (70000, 1000)>
#   Coords	Values
#   (0, 919)	1.0
#   (1, 643)	0.6330990978365678
#   (1, 342)	0.7740707540777677
#   (2, 337)	0.41798948067770014
#   (2, 522)	0.4192245077960194
#   (2, 257)	0.5544261495421839
#   (2, 250)	0.5137378369858571
#   (2, 536)	0.2796796125192049
#   (3, 643)	0.3814837603676932
#   (3, 526)	0.42075999906464995
#   (3, 507)	0.297924651135837
#   (3, 542)	0.4150785930382073
#   (3, 130)	0.4326275209374728
#   (3, 527)	0.47876430081758264
#   (4, 961)	0.4378757325805595
#   (4, 295)	0.35142764819646183
#   (4, 101)	0.4672612705982069
#   (4, 921)	0.3837628927010812
#   (4, 415)	0.4486496930724973
# ...
