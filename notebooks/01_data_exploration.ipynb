# %% [markdown]
# # Data exploration

# %%
import sys
import os
import pandas as pd

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

from src.dataset import load_dataset, load_preprocessed_dataset

# %%
train, test, mapping, output_format = load_dataset()

print(f"Train shape: {train.shape}")
print(train[0:5])
print(f"Test shape: {test.shape}")
print(test[0:5])

# %%
preprocessed_train, preprocessed_test = load_preprocessed_dataset()

# %%
print(f"Preprocessed Train shape: {preprocessed_train.shape}")
pd.set_option('display.max_colwidth', None)
print(preprocessed_train.head())
